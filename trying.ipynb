# %%
from src.logic.state import States = State()s.load_from_json_file('data/maps/n4-s3-60b3a7c0de.json')

# %%
states = {}states[s.__hash__()] = s # assign the states to global dict.

# %%
import networkx as nxG = nx.Graph()

# %%
for ns in s.get_neighbour_states():    G.add_edge(s.__hash__(),ns.__hash__())

# %%
plt.figure(figsize=(4,4))pos=nx.graphviz_layout(G,prog="twopi")nx.draw(G,pos)#img = 'tmp/%s.png' % s.__hash__()#a.axes.imshow(matplotlib.image.imread(img))

# %%
from src.solve.solver import Solverslv = Solver(quit_on_first=False)slv.set_state(s)%prun sols = slv.solve()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/kirill/Backup/projects/snakes2/<ipython-input-6-4f0c50c00f76> in <module>()
#       2 slv = Solver(quit_on_first=False)
#       3 slv.set_state(s)
# ----> 4 get_ipython().magic(u'prun sols = slv.solve()')
#
# /Library/Python/2.7/site-packages/ipython-0.13.dev-py2.7.egg/IPython/core/interactiveshell.pyc in magic(self, arg_s, next_input)
#    1988                 self._magic_locals = sys._getframe(1).f_locals
#    1989             with self.builtin_trap:
# -> 1990                 result = fn(magic_args)
#    1991             # Ensure we're not keeping object references around:
#    1992             self._magic_locals = {}
#
# /Library/Python/2.7/site-packages/ipython-0.13.dev-py2.7.egg/IPython/core/magic.pyc in magic_prun(self, parameter_s, user_mode, opts, arg_lst, prog_ns)
#    1490         prof = profile.Profile()
# ...

# %%
size(sols)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kirill/Backup/projects/snakes2/<ipython-input-7-e55c6ca8e9dd> in <module>()
# ----> 1 size(sols)
#
# NameError: name 'sols' is not defined

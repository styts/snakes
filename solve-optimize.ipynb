# %%
from src.logic.state import Statefrom src.solve.solver import Solver#fn = 'data/maps/340_4-10.json' # ezfn = 'data/maps/8188_3-21.json' # hards = State()slv = Solver(ignore_pickle=True)s.load_from_json_file(fn)slv.set_state(s)sols = slv.solve()slv.draw_graph(size=(8,6))
# Out:
# Populating...
# Solving... shortest: 10 order: 340Pickling... doneDrawing...
# done drawing

# %%
points = []for o in xrange(1,100):    o = 100*o    points.append(o)

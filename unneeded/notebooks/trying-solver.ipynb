# %%
from src.logic.state import States = State()s.load_from_json_file('data/maps/n3-s3-a075793e91.json')

# %%
from src.solve.solver import Solverslv = Solver(quit_on_first=False)slv.set_state(s)sols = slv.solve()
# Out:
# Populating...
# Solving... shortest: 6 order: 42

# %%
slv.draw_graph(size=(5,4))
# Out:
# Drawing...
# done drawing
# <module 'matplotlib.pyplot' from '/Library/Python/2.7/site-packages/matplotlib-1.2.x-py2.7-macosx-10.7-intel.egg/matplotlib/pyplot.pyc'>

# %%
# help ipython auto-reload changed modules (saves me from restarting the kernel evey time i make changes)%load_ext autoreload%autoreload 2
